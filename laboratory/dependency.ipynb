# %%
# %pip install -qU langchain langchain-upstage langchain-community langchain-teddynote ragas langsmith python-dotenv langchain-postgres langgraph langchain-mcp-adapters
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip freeze > ../requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
#%pip install -r requirements.txt
